# %%
import pandas as pd

# %%
data = [1,2,3,4,5]
s = pd.Series(data)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# list does not have a index like pandas Series

# %%
s = [1,2,3,4,5]
print(s)
# Out:
# [1, 2, 3, 4, 5]
