# %% [markdown]
# # Pandas used for data cleaning manipulation selection and data wrangling ,visulization

# %%
import pandas as pd

# %%
# load data 
df = pd.read_csv("employees.csv")

# %% [markdown]
# # Inspect

# %%
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
df.info()

# %% [markdown]
# # Select columns/rows

# %%
df[['EMPLOYEE_ID','FIRST_NAME','SALARY']].head(7)

# %%
df[['EMPLOYEE_ID','FIRST_NAME','SALARY']].tail(3)

# %%
df[['EMPLOYEE_ID','FIRST_NAME','SALARY','EMAIL']].info()

# %% [markdown]
# # iloc
# rows 0:5             #rows from 0 50 5
# Columns 0:4          #columns from 0 to 4

# %%
df.iloc[0:5,1:4]

# %% [markdown]
# # loc
# rows 0:2             #start from 0 go till row 2
# Column 'SALARY'       #Single column
# create list if want multiple columns

# %%
df.loc[0:2,["SALARY","FIRST_NAME","EMAIL"]]
# Out:
#    SALARY FIRST_NAME     EMAIL
# 0    2600     Donald  DOCONNEL
# 1    2600    Douglas    DGRANT
# 2    4400   Jennifer   JWHALEN

# %%
df.loc[df ['SALARY'] > 13000]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 9           100     Steven      King     SKING  515.123.4567  17-JUN-03
# 10          101      Neena   Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102        Lex   De Haan   LDEHAAN  515.123.4569  13-JAN-01
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 9   AD_PRES   24000             -          -              90
# 10    AD_VP   17000             -         100             90
# 11    AD_VP   17000             -         100             90

# %% [markdown]
# # Handlling missing values

# %%
df.isna()
